# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/lab5
# Out:
# /content/drive/MyDrive/lab5

# %%
# !pip install transformers
# !pip install SentencePiece
# !pip install torchmetrics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 59.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.8/728.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
# !chmod 777 run.sh
# !./run.sh
# Out:
# 1
# 2023-07-13 05:25:27.264728: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Adjusting learning rate of group 0 to 1.0000e-06.
# ...

# %%
# !python main.py
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
outputs = model(**inputs)
outputs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d357af70b4d0> in <cell line: 1>()
# ----> 1 outputs = model(**inputs)
#       2 outputs
#
# NameError: name 'model' is not defined

# %%
# inputs.attention_mask[inputs.attenytion_mask == 1] = 0

# %%
inputs.pixel_values.shape

# %%
outputs.pooler_output.shape

# %%
from PIL import Image

from dataset import CustomDataset
from torch.utils.data import Dataset, DataLoader

# Usage example
data_dir = './data'  # Specify the path to the data directory
label_file = './train.txt'  # Specify the path to the train.txt file
dataset = CustomDataset(data_dir, label_file)
train_dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
# for batch in train_dataloader:
#     pass
    # print(batch)
# Accessing a single sample

print(dataset[4:6])
# print(dataset[:5][0])

# %%
image

# %%
# text = 'hello word'

# %%
print(text)

# %%
inputs = processor(image[:5], text, return_tensors="pt")
# outputs = model(**inputs)
inputs

# %%
# print(outputs)

# %%
# inputs

# %%
print(inputs.pixel_values.shape)

# %%
print(outputs.last_hidden_state.shape)
